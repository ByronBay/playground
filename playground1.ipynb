# %%
import cv2
from matplotlib import pyplot as plt

# %%
cv2.__version__
# Out:
# '3.4.1'

# %%
imgBGR = cv2.imread('images/beach.jpeg')
print('size: {} shape: {}'.format(img.size, img.shape))
# Out:
# size: 918750 shape: (350, 875, 3)

# %%
imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgBGR)
plt.imshow(imgRGB)
